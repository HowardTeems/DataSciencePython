# %% [markdown]
# # How to Choose the Number of Clusters

# %% [markdown]
# Using the same code as in the previous exercise, find the WCSS for clustering solutions with 1 to 10 clusters (you can try with more if you wish).
#
# Find the most suitable solutions, run them and compare the results.

# %% [markdown]
# ## Import the relevant libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load data from the csv file: <i> 'Countries_exercise.csv'</i>.

# %%
data = pd.read_csv("Countries-exercise.csv")
data.head()
# Out:
#           name  Longitude   Latitude
# 0        Aruba -69.982677  12.520880
# 1  Afghanistan  66.004734  33.835231
# 2       Angola  17.537368 -12.293361
# 3     Anguilla -63.064989  18.223959
# 4      Albania  20.049834  41.142450

# %% [markdown]
# Remove the duplicate index column from the dataset.

# %% [markdown]
# Plot the <i>'Longtitude'</i> and <i>'Latitude'</i> columns.

# %% [markdown]
# ## Plot the data

# %% [markdown]
# Plot the <i>'Longtitude'</i> and <i>'Latitude'</i> columns.

# %%
plt.scatter(data['Longitude'], data['Latitude'])
plt.xlim(-180, 180)
plt.ylim(-90, 90)
plt.show()

# %% [markdown]
# ## Select the features

# %% [markdown]
# Make sure to select the appropriate features since we are no longer using the categorical variable for our clustering but rather <i>'Longitude'</i> and <i>'Laditude'</i>.

# %%
x = data.iloc[:, 1:3]
x
# Out:
#       Longitude   Latitude
# 0    -69.982677  12.520880
# 1     66.004734  33.835231
# 2     17.537368 -12.293361
# 3    -63.064989  18.223959
# 4     20.049834  41.142450
# 5     19.953288  60.214887
# 6      1.560544  42.542291
# 7     54.300167  23.905282
# 8    -65.179807 -35.381349
# 9     44.929933  40.289526
# 10  -170.718026 -14.304460
# 11    19.921090 -80.508579
# 12   123.583838 -12.429932
# 13    69.226668 -49.248955
# 14   -61.794693  17.277500
# 15   134.491000 -25.732887
# 16    14.126476  47.585494
# 17    47.545999  40.288272
# 18    29.875122  -3.359397
# 19     4.640651  50.639816
# 20     2.327853   9.641760
# 21    -1.754566  12.269538
# 22    90.238127  23.867312
# 23    25.215529  42.768903
# 24    50.541969  26.042051
# 25   -98.307770  61.362063
# 26   -76.628430  24.290367
# 27    17.768767  44.174501
# 28   -62.840678  17.898805
# 29    28.032093  53.531314
# ..          ...        ...
# 211   18.644925  15.333338
# 212    0.962328   8.525314
# ...

# %% [markdown]
# Use 4 clusters initially.

# %%
kmeans = KMeans(4)

# %%
kmeans.fit(x)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# ### Clustering results

# %%
identified_clusters = kmeans.fit_predict(x)
identified_clusters
# Out:
# array([2, 3, 3, 2, 0, 0, 0, 3, 2, 3, 2, 3, 1, 3, 2, 1, 0, 3, 3, 0, 0, 0,
#        1, 0, 3, 2, 2, 0, 2, 0, 2, 2, 2, 2, 2, 1, 1, 3, 3, 0, 2, 1, 0, 3,
#        3, 3, 2, 2, 3, 0, 2, 2, 2, 2, 0, 0, 0, 0, 3, 2, 0, 2, 0, 2, 3, 3,
#        0, 0, 3, 0, 1, 2, 0, 0, 1, 3, 0, 3, 0, 0, 0, 0, 0, 3, 0, 2, 0, 2,
#        1, 2, 1, 3, 2, 0, 2, 0, 1, 0, 3, 1, 3, 0, 3, 3, 0, 3, 0, 2, 0, 3,
#        1, 3, 3, 3, 3, 1, 2, 2, 1, 0, 3, 1, 3, 0, 0, 2, 0, 3, 3, 0, 0, 0,
#        1, 2, 0, 0, 0, 3, 3, 2, 1, 0, 0, 0, 1, 0, 1, 1, 3, 0, 2, 3, 3, 1,
#        3, 1, 0, 1, 0, 2, 2, 0, 0, 3, 1, 1, 3, 3, 2, 2, 2, 1, 1, 1, 0, 2,
#        1, 0, 2, 3, 2, 3, 0, 1, 3, 0, 3, 3, 3, 0, 1, 2, 0, 1, 0, 2, 0, 3,
#        3, 2, 0, 3, 2, 0, 0, 0, 3, 2, 3, 3, 2, 3, 0, 1, 3, 3, 1, 2, 2, 0,
#        0, 1, 3, 3, 0, 2, 2, 3, 0, 2, 2, 2, 2, 1, 1, 2, 2, 3, 3, 3, 3])

# %%
data_with_clusters = data.copy()
data_with_clusters['Cluster'] = identified_clusters
data_with_clusters
# Out:
#                         name   Longitude   Latitude  Cluster
# 0                      Aruba  -69.982677  12.520880        2
# 1                Afghanistan   66.004734  33.835231        3
# 2                     Angola   17.537368 -12.293361        3
# 3                   Anguilla  -63.064989  18.223959        2
# 4                    Albania   20.049834  41.142450        0
# 5                      Aland   19.953288  60.214887        0
# 6                    Andorra    1.560544  42.542291        0
# 7       United Arab Emirates   54.300167  23.905282        3
# 8                  Argentina  -65.179807 -35.381349        2
# 9                    Armenia   44.929933  40.289526        3
# 10            American Samoa -170.718026 -14.304460        2
# 11                Antarctica   19.921090 -80.508579        3
# 12   Ashmore and Cartier Is.  123.583838 -12.429932        1
# 13    Fr. S. Antarctic Lands   69.226668 -49.248955        3
# ...

# %% [markdown]
# Plot the data once again but separate the data by the clusters we defined.

# %% [markdown]
# ## Plot the data

# %%
plt.scatter(data_with_clusters['Longitude'], data_with_clusters['Latitude'], c=data_with_clusters['Cluster'])
plt.xlim(-180, 180)
plt.ylim(-90, 90)
plt.show()

# %% [markdown]
# ## Selecting the number of clusters

# %% [markdown]
# ### WCSS

# %% [markdown]
# Use the ingerated <i>sklearn</i> method <i> 'inertia_' </i>.

# %%
kmeans.inertia_
# Out:
# 256573.08675934302

# %% [markdown]
# Write a loop that calculates and saves the WCSS for any number of clusters from 1 up to 10 (or more if you wish).

# %%
wcss = []

for i in range (1, 10) :
    kmeans = KMeans(i)
    kmeans.fit(x)
    wcss_iter = kmeans.inertia_
    wcss.append(wcss_iter)

# %%
wcss
# Out:
# [1413859.6798344273,
#  657012.0797586325,
#  325235.52237055893,
#  256595.2235602978,
#  192356.48001889366,
#  152258.09346318943,
#  126816.75754582995,
#  102932.14383201557,
#  84927.05022223276]

# %% [markdown]
# ### The Elbow Method

# %%
number_clusters = range(1, 10)
plt.plot(number_clusters, wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Cluster')
plt.ylabel('Within-Cluster Sum of Squares')
# Out:
# Text(0, 0.5, 'Within-Cluster Sum of Squares')

# %% [markdown]
# Based on the Elbow Curve, plot several graphs with the appropriate amounts of clusters you believe would best fit the data.

# %% [markdown]
# There is not much improvement after 5 clusters.

# %% [markdown]
# Compare the scatter plots to determine which one to use in our further analysis.

# %% [markdown]
# <i>Hint: we already created the scatter plot for 4 clusters, so we only have to slightly alter our code.</i>

# %%
kmeans = KMeans(5)
kmeans.fit(x)
identified_clusters5 = kmeans.fit_predict(x)
data_with_clusters5 = data.copy()
data_with_clusters5['Cluster'] = identified_clusters5

# %%
plt.scatter(data_with_clusters5['Longitude'], data_with_clusters5['Latitude'], c=data_with_clusters5['Cluster'], cmap='rainbow')
plt.xlim(-180, 180)
plt.ylim(-90, 90)
plt.show()

# %% [markdown]
# It shows clusters of the Americas, Europe with NW Africa, the rest of Africa with the Near East, the rest of Asia and western Oceana, and the rest of Oceana.  The discontinuity at the theoretical Date Line, +/-180 Longitude, causes points to be divided into separate clusters even though they are actually close.  Fiji and Tonga are two examples.
